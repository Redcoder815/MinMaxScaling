# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/MinMaxScaling/blob/main/minMaxScaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipdb
import ipdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/Titanic-Dataset.csv')
# df.info()
# df.head()

df.duplicated()
cat_col = [col for col in df.columns if df[col].dtype == 'object']
num_col = [col for col in df.columns if df[col].dtype != 'object']

# print('catergory column', cat_col)
# print('numerical column', num_col)

# df[cat_col].nunique()

df1 = df.drop(columns = ['Name','Ticket','Cabin'])
df1.dropna(subset=['Embarked'], inplace=True)
df1['Age'].fillna(df1['Age'].mean(),inplace=True)
round((df1.isnull().sum()/df1.shape[0])*100,2)
# display(df1)
# import matplotlib.pyplot as plt
# plt.boxplot(df1['Age'], vert=False)
# plt.xlabel('Age')
# plt.ylabel('data')
# plt.title('Box plot of age')
# plt.show()

mean = df1['Age'].mean()
std = df1['Age'].std()

lower_bound = mean - 2 * std
upper_bound = mean + 2 * std

df2 = df1[(df1['Age']>=lower_bound) & (df1['Age']<=upper_bound)]
import ipdb
# ipdb.set_trace()
# print('Print after selection')
# print(df2)
X = df2[['Pclass','Sex','Age', 'SibSp','Parch','Fare','Embarked']]
Y = df2['Survived']
# ipdb.set_trace()
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
num_col = [col for col in X.columns if X[col].dtype != object]
ipdb.set_trace()
x1 = X

x1[num_col] = scaler.fit_transform(x1[num_col])
ipdb.set_trace()
x1.head()
# Out:
# /tmp/ipython-input-1595253512.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Age'].fillna(df1['Age'].mean(),inplace=True)
# --Return--
# None
# > /tmp/ipython-input-1595253512.py(47)<cell line: 0>()
#      46 num_col = [col for col in X.columns if X[col].dtype != object]
# ---> 47 ipdb.set_trace()
#      48 x1 = X
#
# ipdb> x1
#      Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0         3    male  22.000000      1      0   7.2500        S
# ...
